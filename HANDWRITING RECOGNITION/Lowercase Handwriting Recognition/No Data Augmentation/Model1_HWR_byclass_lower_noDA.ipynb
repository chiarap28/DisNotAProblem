# %%
pip install emnist
# Out:
# Collecting emnist
#   Downloading https://files.pythonhosted.org/packages/d1/f4/78b24acbef9e8fe976dda700f16a3606f3b8363b015bc555f8050fbbd8ac/emnist-0.0-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from emnist) (1.18.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from emnist) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from emnist) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (1.24.3)
# Installing collected packages: emnist
# Successfully installed emnist-0.0

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path
from collections import Counter

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from emnist import list_datasets, extract_training_samples, extract_test_samples

# %%
# load emnist dataset 'by class'

images, labels = extract_training_samples('byclass')
images_test, labels_test = extract_test_samples('byclass')
# Out:
# Downloading emnist.zip: 536MB [00:03, 185MB/s]

# %%
# find index of uppercase letters

tr_index_UPP = [i for i in range(len(labels)) if labels[i]>=36 and labels[i] <= 61] 
ts_index_UPP = [i for i in range(len(labels_test)) if labels_test[i]>=36 and labels_test[i] <= 61]

# %%
# save images and labels in uppercase

im_train_UPP = images[tr_index_UPP]
im_test_UPP = images_test[ts_index_UPP]
lab_train_UPP = labels[tr_index_UPP]
lab_test_UPP = labels_test[ts_index_UPP]

# %%
# reformulate labels for application of built-in function 'to_categorical'

alf_UPP = {
       36: 0,
       37: 1,
       38: 2,
       39: 3,
       40: 4,
       41: 5,
       42: 6,
       43: 7,
       44: 8,
       45: 9,
       46: 10,
       47: 11,
       48: 12,
       49: 13,
       50: 14,
       51: 15,
       52: 16,
       53: 17,
       54: 18,
       55: 19,
       56: 20,
       57: 21,
       58: 22,
       59: 23,
       60: 24,
       61: 25,
       }

lab_train_UPP = [alf_UPP[label] for label in lab_train_UPP]
lab_test_UPP = [alf_UPP[label] for label in lab_test_UPP]

# %%
# check labels

lab_train_UPP[0]
# Out:
# 0

# %%
# define image width and height and batch size

# Batch size for training and validation
batch_size = 32

# Desired image dimensions
img_width = 28
img_height = 28

# %%
# split training set in traininig and validation set

def split_data(images, labels, train_size=0.9, shuffle=True):
    # 1. Get the total size of the dataset
    size = len(images)
    # 2. Make an indices array and shuffle it, if required
    indices = np.arange(size)
    if shuffle:
        np.random.shuffle(indices)
    # 3. Get the size of training samples
    train_samples = int(size * train_size)
    # 4. Split data into training and validation sets
    x_train, y_train = images[indices[:train_samples]], labels[indices[:train_samples]]
    x_valid, y_valid = images[indices[train_samples:]], labels[indices[train_samples:]]
    return x_train, x_valid, y_train, y_valid

# %%
# Splitting data into training and validation sets
x_train_UPP, x_valid_UPP, y_train_UPP, y_valid_UPP = split_data(np.array(im_train_UPP), np.array(lab_train_UPP))

# %%
# to categorical 

y_train_UPP = tf.keras.utils.to_categorical(y_train_UPP, 26)
y_valid_UPP = tf.keras.utils.to_categorical(y_valid_UPP, 26)
lab_test_UPP = tf.keras.utils.to_categorical(lab_test_UPP, 26)

# %%
# normalize training, validation and test data

x_train_UPP = tf.keras.utils.normalize(x_train_UPP, axis=1)
x_valid_UPP = tf.keras.utils.normalize(x_valid_UPP, axis=1)
im_test_UPP = tf.keras.utils.normalize(im_test_UPP, axis=1)

# %%
# build model

def build_model():
    # Inputs to the model
    input_img = layers.Input(
        shape=(img_width, img_height, 1), name="image", dtype="float32"
    )
    # First conv block
    x = layers.Conv2D(
        64,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv1",
    )(input_img)
    x = layers.MaxPooling2D((2, 2),padding='same',name="pool1")(x)

    # Second conv block
    x = layers.Conv2D(
        128,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv2",
    )(x)
    x = layers.MaxPooling2D((2, 2), padding='same',name="pool2")(x)
    #x = layers.Flatten()(x)
    # We have used two max pool with pool size and strides 2.
    # Hence, downsampled feature maps are 4x smaller. The number of
    # filters in the last layer is 64. Reshape accordingly before
    # passing the output to the RNN part of the model
    new_shape = ((img_width // 4), (img_height // 4) * 128)
    x = layers.Reshape(target_shape=new_shape, name="reshape")(x)
    x = layers.Dense(64, activation="relu", name="dense1")(x)
    x = layers.Dropout(0.2)(x)

    # RNNs
    x = layers.Bidirectional(layers.LSTM(64, return_sequences=True, dropout=0.25, name='bilstm1'))(x)
    #x = layers.Flatten()(x)
    x = layers.Bidirectional(layers.LSTM(32, return_sequences=True, dropout=0.25, name='bilstm2'))(x)
    x = layers.Flatten()(x)
    # Output layer
    x = layers.Dense(units=128, activation='sigmoid', name='dense_1')(x)
    output = layers.Dense(units=26, activation="softmax", name="dense2")(x)

    # Define the model
    model = keras.models.Model(
        inputs=input_img, outputs=output, name="ocr_model_v1"
    )
    # Optimizer
    opt = keras.optimizers.Adam()
    # Compile the model and return
    model.compile(loss='categorical_crossentropy',optimizer=opt, metrics=['accuracy'])

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "ocr_model_v1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image (InputLayer)           [(None, 28, 28, 1)]       0
# _________________________________________________________________
# Conv1 (Conv2D)               (None, 28, 28, 64)        640
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 14, 14, 64)        0
# _________________________________________________________________
# Conv2 (Conv2D)               (None, 14, 14, 128)       73856
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 7, 7, 128)         0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 896)            0
# _________________________________________________________________
# dense1 (Dense)               (None, 7, 64)             57408
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 64)             0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 7, 128)            66048
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 7, 64)             41216
# _________________________________________________________________
# flatten (Flatten)            (None, 448)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               57472
# _________________________________________________________________
# dense2 (Dense)               (None, 26)                3354
# =================================================================
# Total params: 299,994
# Trainable params: 299,994
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, to_file='/content/drive/My Drive/TESI/Models/Immagini/model1_byclass_lower_noDA.png')

# %%
epochs = 100
early_stopping_patience = 10
# Add early stopping
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_accuracy", patience=early_stopping_patience, restore_best_weights=True, verbose=1
)

# Model CheckPoint
cp = keras.callbacks.ModelCheckpoint('/content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5',
                                     verbose=1,
                                     monitor='val_accuracy',
                                     save_best_only=True,
                                     mode='max')

# %%
# fit model
history1_UPP = model.fit(x_train_UPP,y_train_UPP,
                    validation_data=(x_valid_UPP,y_valid_UPP),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[cp, early_stopping])
# Out:
# Epoch 1/100
# 4611/4611 [==============================] - ETA: 0s - loss: 0.4748 - accuracy: 0.8623
# Epoch 00001: val_accuracy improved from -inf to 0.93290, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 51s 11ms/step - loss: 0.4748 - accuracy: 0.8623 - val_loss: 0.2218 - val_accuracy: 0.9329
# Epoch 2/100
# 4611/4611 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9301
# Epoch 00002: val_accuracy improved from 0.93290 to 0.94394, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.2258 - accuracy: 0.9301 - val_loss: 0.1803 - val_accuracy: 0.9439
# Epoch 3/100
# 4608/4611 [============================>.] - ETA: 0s - loss: 0.1900 - accuracy: 0.9408
# Epoch 00003: val_accuracy improved from 0.94394 to 0.94809, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 51s 11ms/step - loss: 0.1899 - accuracy: 0.9408 - val_loss: 0.1695 - val_accuracy: 0.9481
# Epoch 4/100
# 4608/4611 [============================>.] - ETA: 0s - loss: 0.1713 - accuracy: 0.9456
# Epoch 00004: val_accuracy improved from 0.94809 to 0.94888, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 51s 11ms/step - loss: 0.1713 - accuracy: 0.9456 - val_loss: 0.1647 - val_accuracy: 0.9489
# Epoch 5/100
# 4607/4611 [============================>.] - ETA: 0s - loss: 0.1591 - accuracy: 0.9495
# Epoch 00005: val_accuracy improved from 0.94888 to 0.94931, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1592 - accuracy: 0.9494 - val_loss: 0.1642 - val_accuracy: 0.9493
# Epoch 6/100
# 4610/4611 [============================>.] - ETA: 0s - loss: 0.1508 - accuracy: 0.9521
# Epoch 00006: val_accuracy improved from 0.94931 to 0.95364, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 51s 11ms/step - loss: 0.1508 - accuracy: 0.9521 - val_loss: 0.1524 - val_accuracy: 0.9536
# Epoch 7/100
# 4610/4611 [============================>.] - ETA: 0s - loss: 0.1453 - accuracy: 0.9530
# Epoch 00007: val_accuracy improved from 0.95364 to 0.95382, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 51s 11ms/step - loss: 0.1453 - accuracy: 0.9530 - val_loss: 0.1488 - val_accuracy: 0.9538
# Epoch 8/100
# 4607/4611 [============================>.] - ETA: 0s - loss: 0.1397 - accuracy: 0.9544
# Epoch 00008: val_accuracy improved from 0.95382 to 0.95553, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 51s 11ms/step - loss: 0.1397 - accuracy: 0.9544 - val_loss: 0.1453 - val_accuracy: 0.9555
# Epoch 9/100
# 4610/4611 [============================>.] - ETA: 0s - loss: 0.1353 - accuracy: 0.9562
# Epoch 00009: val_accuracy did not improve from 0.95553
# 4611/4611 [==============================] - 51s 11ms/step - loss: 0.1353 - accuracy: 0.9562 - val_loss: 0.1481 - val_accuracy: 0.9543
# Epoch 10/100
# 4607/4611 [============================>.] - ETA: 0s - loss: 0.1325 - accuracy: 0.9563
# Epoch 00010: val_accuracy did not improve from 0.95553
# 4611/4611 [==============================] - 49s 11ms/step - loss: 0.1325 - accuracy: 0.9563 - val_loss: 0.1532 - val_accuracy: 0.9552
# Epoch 11/100
# 4608/4611 [============================>.] - ETA: 0s - loss: 0.1287 - accuracy: 0.9584
# Epoch 00011: val_accuracy did not improve from 0.95553
# 4611/4611 [==============================] - 49s 11ms/step - loss: 0.1287 - accuracy: 0.9584 - val_loss: 0.1493 - val_accuracy: 0.9555
# Epoch 12/100
# 4610/4611 [============================>.] - ETA: 0s - loss: 0.1246 - accuracy: 0.9598
# Epoch 00012: val_accuracy improved from 0.95553 to 0.95639, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1245 - accuracy: 0.9598 - val_loss: 0.1467 - val_accuracy: 0.9564
# Epoch 13/100
# 4609/4611 [============================>.] - ETA: 0s - loss: 0.1220 - accuracy: 0.9600
# Epoch 00013: val_accuracy did not improve from 0.95639
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1219 - accuracy: 0.9600 - val_loss: 0.1492 - val_accuracy: 0.9550
# Epoch 14/100
# 4610/4611 [============================>.] - ETA: 0s - loss: 0.1226 - accuracy: 0.9602
# Epoch 00014: val_accuracy improved from 0.95639 to 0.95687, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1226 - accuracy: 0.9602 - val_loss: 0.1480 - val_accuracy: 0.9569
# Epoch 15/100
# 4606/4611 [============================>.] - ETA: 0s - loss: 0.1198 - accuracy: 0.9608
# Epoch 00015: val_accuracy did not improve from 0.95687
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1198 - accuracy: 0.9608 - val_loss: 0.1485 - val_accuracy: 0.9552
# Epoch 16/100
# 4610/4611 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9612
# Epoch 00016: val_accuracy did not improve from 0.95687
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1176 - accuracy: 0.9612 - val_loss: 0.1456 - val_accuracy: 0.9558
# Epoch 17/100
# 4608/4611 [============================>.] - ETA: 0s - loss: 0.1156 - accuracy: 0.9616
# Epoch 00017: val_accuracy improved from 0.95687 to 0.95755, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1156 - accuracy: 0.9616 - val_loss: 0.1416 - val_accuracy: 0.9575
# Epoch 18/100
# 4610/4611 [============================>.] - ETA: 0s - loss: 0.1147 - accuracy: 0.9619
# Epoch 00018: val_accuracy did not improve from 0.95755
# 4611/4611 [==============================] - 49s 11ms/step - loss: 0.1147 - accuracy: 0.9619 - val_loss: 0.1458 - val_accuracy: 0.9559
# Epoch 19/100
# 4606/4611 [============================>.] - ETA: 0s - loss: 0.1161 - accuracy: 0.9614
# Epoch 00019: val_accuracy did not improve from 0.95755
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1161 - accuracy: 0.9614 - val_loss: 0.1449 - val_accuracy: 0.9560
# Epoch 20/100
# 4611/4611 [==============================] - ETA: 0s - loss: 0.1115 - accuracy: 0.9627
# Epoch 00020: val_accuracy did not improve from 0.95755
# 4611/4611 [==============================] - 49s 11ms/step - loss: 0.1115 - accuracy: 0.9627 - val_loss: 0.1498 - val_accuracy: 0.9558
# Epoch 21/100
# 4610/4611 [============================>.] - ETA: 0s - loss: 0.1128 - accuracy: 0.9620
# Epoch 00021: val_accuracy did not improve from 0.95755
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1128 - accuracy: 0.9620 - val_loss: 0.1495 - val_accuracy: 0.9561
# Epoch 22/100
# 4611/4611 [==============================] - ETA: 0s - loss: 0.1106 - accuracy: 0.9633
# Epoch 00022: val_accuracy improved from 0.95755 to 0.95803, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1106 - accuracy: 0.9633 - val_loss: 0.1438 - val_accuracy: 0.9580
# Epoch 23/100
# 4608/4611 [============================>.] - ETA: 0s - loss: 0.1091 - accuracy: 0.9636
# Epoch 00023: val_accuracy did not improve from 0.95803
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1091 - accuracy: 0.9636 - val_loss: 0.1541 - val_accuracy: 0.9550
# Epoch 24/100
# 4611/4611 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9642
# Epoch 00024: val_accuracy did not improve from 0.95803
# 4611/4611 [==============================] - 49s 11ms/step - loss: 0.1079 - accuracy: 0.9642 - val_loss: 0.1506 - val_accuracy: 0.9555
# Epoch 25/100
# 4608/4611 [============================>.] - ETA: 0s - loss: 0.1078 - accuracy: 0.9641
# Epoch 00025: val_accuracy improved from 0.95803 to 0.95895, saving model to /content/drive/My Drive/TESI/Models/model1LOW_byclass_noDA.h5
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1079 - accuracy: 0.9641 - val_loss: 0.1459 - val_accuracy: 0.9589
# Epoch 26/100
# 4611/4611 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9642
# Epoch 00026: val_accuracy did not improve from 0.95895
# 4611/4611 [==============================] - 49s 11ms/step - loss: 0.1071 - accuracy: 0.9642 - val_loss: 0.1451 - val_accuracy: 0.9582
# Epoch 27/100
# 4607/4611 [============================>.] - ETA: 0s - loss: 0.1073 - accuracy: 0.9642
# Epoch 00027: val_accuracy did not improve from 0.95895
# 4611/4611 [==============================] - 49s 11ms/step - loss: 0.1073 - accuracy: 0.9642 - val_loss: 0.1514 - val_accuracy: 0.9557
# Epoch 28/100
# 4610/4611 [============================>.] - ETA: 0s - loss: 0.1084 - accuracy: 0.9638
# Epoch 00028: val_accuracy did not improve from 0.95895
# 4611/4611 [==============================] - 51s 11ms/step - loss: 0.1083 - accuracy: 0.9638 - val_loss: 0.1545 - val_accuracy: 0.9560
# Epoch 29/100
# 4610/4611 [============================>.] - ETA: 0s - loss: 0.1055 - accuracy: 0.9645
# Epoch 00029: val_accuracy did not improve from 0.95895
# 4611/4611 [==============================] - 49s 11ms/step - loss: 0.1055 - accuracy: 0.9645 - val_loss: 0.1464 - val_accuracy: 0.9571
# Epoch 30/100
# 4609/4611 [============================>.] - ETA: 0s - loss: 0.1072 - accuracy: 0.9644
# Epoch 00030: val_accuracy did not improve from 0.95895
# 4611/4611 [==============================] - 49s 11ms/step - loss: 0.1072 - accuracy: 0.9644 - val_loss: 0.1565 - val_accuracy: 0.9569
# Epoch 31/100
# 4607/4611 [============================>.] - ETA: 0s - loss: 0.1074 - accuracy: 0.9643
# Epoch 00031: val_accuracy did not improve from 0.95895
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1075 - accuracy: 0.9643 - val_loss: 0.1492 - val_accuracy: 0.9555
# Epoch 32/100
# 4608/4611 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9644
# Epoch 00032: val_accuracy did not improve from 0.95895
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1058 - accuracy: 0.9644 - val_loss: 0.1488 - val_accuracy: 0.9576
# Epoch 33/100
# 4610/4611 [============================>.] - ETA: 0s - loss: 0.1048 - accuracy: 0.9645
# Epoch 00033: val_accuracy did not improve from 0.95895
# 4611/4611 [==============================] - 50s 11ms/step - loss: 0.1048 - accuracy: 0.9645 - val_loss: 0.1453 - val_accuracy: 0.9582
# Epoch 34/100
# 4609/4611 [============================>.] - ETA: 0s - loss: 0.1063 - accuracy: 0.9641
# Epoch 00034: val_accuracy did not improve from 0.95895
# 4611/4611 [==============================] - 51s 11ms/step - loss: 0.1063 - accuracy: 0.9641 - val_loss: 0.1531 - val_accuracy: 0.9571
# Epoch 35/100
# 4611/4611 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9643
# Epoch 00035: val_accuracy did not improve from 0.95895
# Restoring model weights from the end of the best epoch.
# 4611/4611 [==============================] - 49s 11ms/step - loss: 0.1053 - accuracy: 0.9643 - val_loss: 0.1520 - val_accuracy: 0.9570
# Epoch 00035: early stopping

# %%
plt.figure(figsize=(16,9))
# summarize history for accuracy
plt.plot(history1_UPP.history['accuracy'])
plt.plot(history1_UPP.history['val_accuracy'])
plt.title('Model 1 lowercase letters accuracy (without Data Augmentation)')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()
plt.figure(figsize=(16,9))

# summarize history for loss
plt.plot(history1_UPP.history['loss'])
plt.plot(history1_UPP.history['val_loss'])
plt.title('Model 1 lowercase letters loss (without Data Augmentation)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
evaluation = model.evaluate(im_test_UPP, lab_test_UPP)
# Out:
# 846/846 [==============================] - 5s 5ms/step - loss: 0.1405 - accuracy: 0.9594

# %%
evaluation
# Out:
# [0.14047375321388245, 0.9594219923019409]
