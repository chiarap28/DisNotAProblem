# %%
pip install emnist
# Out:
# Collecting emnist
#   Downloading https://files.pythonhosted.org/packages/d1/f4/78b24acbef9e8fe976dda700f16a3606f3b8363b015bc555f8050fbbd8ac/emnist-0.0-py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from emnist) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from emnist) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from emnist) (1.18.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2020.6.20)
# Installing collected packages: emnist
# Successfully installed emnist-0.0

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path
from collections import Counter

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from emnist import list_datasets, extract_training_samples, extract_test_samples

# %%
# load emnist dataset 'by class'

images, labels = extract_training_samples('byclass')
images_test, labels_test = extract_test_samples('byclass')
# Out:
# Downloading emnist.zip: 536MB [00:03, 142MB/s]

# %%
# find index of uppercase letters

tr_index_UPP = [i for i in range(len(labels)) if labels[i]>=36 and labels[i] <= 61] 
ts_index_UPP = [i for i in range(len(labels_test)) if labels_test[i]>=36 and labels_test[i] <= 61]

# %%
# save images and labels in uppercase

im_train_UPP = images[tr_index_UPP]
im_test_UPP = images_test[ts_index_UPP]
lab_train_UPP = labels[tr_index_UPP]
lab_test_UPP = labels_test[ts_index_UPP]

# %%
# reformulate labels for application of built-in function 'to_categorical'

alf_UPP = {
       36: 0,
       37: 1,
       38: 2,
       39: 3,
       40: 4,
       41: 5,
       42: 6,
       43: 7,
       44: 8,
       45: 9,
       46: 10,
       47: 11,
       48: 12,
       49: 13,
       50: 14,
       51: 15,
       52: 16,
       53: 17,
       54: 18,
       55: 19,
       56: 20,
       57: 21,
       58: 22,
       59: 23,
       60: 24,
       61: 25,
       }

lab_train_UPP = [alf_UPP[label] for label in lab_train_UPP]
lab_test_UPP = [alf_UPP[label] for label in lab_test_UPP]

# %%
# check labels

lab_train_UPP[0]
# Out:
# 0

# %%
# define image width and height and batch size

# Batch size for training and validation
batch_size = 32

# Desired image dimensions
img_width = 28
img_height = 28

# %%
# split training set in traininig and validation set

def split_data(images, labels, train_size=0.9, shuffle=True):
    # 1. Get the total size of the dataset
    size = len(images)
    # 2. Make an indices array and shuffle it, if required
    indices = np.arange(size)
    if shuffle:
        np.random.shuffle(indices)
    # 3. Get the size of training samples
    train_samples = int(size * train_size)
    # 4. Split data into training and validation sets
    x_train, y_train = images[indices[:train_samples]], labels[indices[:train_samples]]
    x_valid, y_valid = images[indices[train_samples:]], labels[indices[train_samples:]]
    return x_train, x_valid, y_train, y_valid

# %%
# Splitting data into training and validation sets
x_train_UPP, x_valid_UPP, y_train_UPP, y_valid_UPP = split_data(np.array(im_train_UPP), np.array(lab_train_UPP))

# %%
# to categorical 

y_train_UPP = tf.keras.utils.to_categorical(y_train_UPP, 26)
y_valid_UPP = tf.keras.utils.to_categorical(y_valid_UPP, 26)

# %%
# normalize training, validation and test data

x_train_UPP = tf.keras.utils.normalize(x_train_UPP, axis=1)
x_valid_UPP = tf.keras.utils.normalize(x_valid_UPP, axis=1)
im_test_UPP = tf.keras.utils.normalize(im_test_UPP, axis=1)

# %%
# using data augmentation

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(featurewise_center=True,
                                                          featurewise_std_normalization=True,
                                                          rotation_range=20,
                                                          width_shift_range=0.2,
                                                          height_shift_range=0.2,
                                                          horizontal_flip=True)
valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(featurewise_center=True,
                                                          featurewise_std_normalization=True,
                                                          rotation_range=20,
                                                          width_shift_range=0.2,
                                                          height_shift_range=0.2,
                                                          horizontal_flip=True)

x_train_UPP = np.reshape(x_train_UPP, (len(x_train_UPP),img_width, img_width, 1))
x_valid_UPP = np.reshape(x_valid_UPP, (len(x_valid_UPP),img_width, img_width, 1))
im_test_UPP = np.reshape(im_test_UPP, (len(im_test_UPP), img_width, img_height, 1))

train_datagen.fit(x_train_UPP)
valid_datagen.fit(x_valid_UPP)

# %%
# build model

def build_model():
    # Inputs to the model
    input_img = layers.Input(
        shape=(img_width, img_height, 1), name="image", dtype="float32"
    )
    # First conv block
    x = layers.Conv2D(
        64,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv1",
    )(input_img)
    x = layers.MaxPooling2D((2, 2),padding='same',name="pool1")(x)

    # Second conv block
    x = layers.Conv2D(
        128,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv2",
    )(x)
    x = layers.MaxPooling2D((2, 2), padding='same',name="pool2")(x)
    #x = layers.Flatten()(x)
    # We have used two max pool with pool size and strides 2.
    # Hence, downsampled feature maps are 4x smaller. The number of
    # filters in the last layer is 64. Reshape accordingly before
    # passing the output to the RNN part of the model
    new_shape = ((img_width // 4), (img_height // 4) * 128)
    x = layers.Reshape(target_shape=new_shape, name="reshape")(x)
    x = layers.Dense(64, activation="relu", name="dense1")(x)
    x = layers.Dropout(0.2)(x)

    # RNNs
    x = layers.Bidirectional(layers.LSTM(64, return_sequences=True, dropout=0.25, name='bilstm1'))(x)
    #x = layers.Flatten()(x)
    x = layers.Bidirectional(layers.LSTM(32, return_sequences=True, dropout=0.25, name='bilstm2'))(x)
    x = layers.Flatten()(x)
    # Output layer
    x = layers.Dense(units=128, activation='sigmoid', name='dense_1')(x)
    output = layers.Dense(units=26, activation="softmax", name="dense2")(x)

    # Define the model
    model = keras.models.Model(
        inputs=input_img, outputs=output, name="ocr_model_v1"
    )
    # Optimizer
    opt = keras.optimizers.Adam()
    # Compile the model and return
    model.compile(loss='categorical_crossentropy',optimizer=opt, metrics=['accuracy'])

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "ocr_model_v1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image (InputLayer)           [(None, 28, 28, 1)]       0
# _________________________________________________________________
# Conv1 (Conv2D)               (None, 28, 28, 64)        640
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 14, 14, 64)        0
# _________________________________________________________________
# Conv2 (Conv2D)               (None, 14, 14, 128)       73856
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 7, 7, 128)         0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 896)            0
# _________________________________________________________________
# dense1 (Dense)               (None, 7, 64)             57408
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 64)             0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 7, 128)            66048
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 7, 64)             41216
# _________________________________________________________________
# flatten (Flatten)            (None, 448)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               57472
# _________________________________________________________________
# dense2 (Dense)               (None, 26)                3354
# =================================================================
# Total params: 299,994
# Trainable params: 299,994
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, to_file='/content/drive/My Drive/TESI/Models/Immagini/model1_byclass_lower.png')

# %%
epochs = 100
early_stopping_patience = 10
# Add early stopping
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_accuracy", patience=early_stopping_patience, restore_best_weights=True, verbose=1
)

# Model CheckPoint
cp = keras.callbacks.ModelCheckpoint('/content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5',
                                     verbose=1,
                                     monitor='val_accuracy',
                                     save_best_only=True,
                                     mode='max')

# %%
# fit model
history1_UPP = model.fit(train_datagen.flow(x_train_UPP,y_train_UPP, batch_size=batch_size),
                    validation_data=valid_datagen.flow(x_valid_UPP,y_valid_UPP, batch_size=batch_size),
                    steps_per_epoch=len(x_train_UPP)//batch_size,
                    validation_steps=len(x_valid_UPP)//batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[cp, early_stopping])
# Out:
# Epoch 1/100
# 4607/4610 [============================>.] - ETA: 0s - loss: 0.9972 - accuracy: 0.6892
# Epoch 00001: val_accuracy improved from -inf to 0.80273, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 79s 17ms/step - loss: 0.9970 - accuracy: 0.6893 - val_loss: 0.6073 - val_accuracy: 0.8027
# Epoch 2/100
# 4609/4610 [============================>.] - ETA: 0s - loss: 0.5975 - accuracy: 0.8053
# Epoch 00002: val_accuracy improved from 0.80273 to 0.83942, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 79s 17ms/step - loss: 0.5976 - accuracy: 0.8053 - val_loss: 0.4941 - val_accuracy: 0.8394
# Epoch 3/100
# 4609/4610 [============================>.] - ETA: 0s - loss: 0.5150 - accuracy: 0.8311
# Epoch 00003: val_accuracy improved from 0.83942 to 0.85876, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 78s 17ms/step - loss: 0.5149 - accuracy: 0.8311 - val_loss: 0.4385 - val_accuracy: 0.8588
# Epoch 4/100
# 4609/4610 [============================>.] - ETA: 0s - loss: 0.4718 - accuracy: 0.8444
# Epoch 00004: val_accuracy improved from 0.85876 to 0.87103, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 78s 17ms/step - loss: 0.4718 - accuracy: 0.8444 - val_loss: 0.3912 - val_accuracy: 0.8710
# Epoch 5/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.4440 - accuracy: 0.8527
# Epoch 00005: val_accuracy improved from 0.87103 to 0.87598, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 78s 17ms/step - loss: 0.4439 - accuracy: 0.8528 - val_loss: 0.3813 - val_accuracy: 0.8760
# Epoch 6/100
# 4610/4610 [==============================] - ETA: 0s - loss: 0.4244 - accuracy: 0.8604
# Epoch 00006: val_accuracy improved from 0.87598 to 0.87988, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 79s 17ms/step - loss: 0.4244 - accuracy: 0.8604 - val_loss: 0.3692 - val_accuracy: 0.8799
# Epoch 7/100
# 4610/4610 [==============================] - ETA: 0s - loss: 0.4106 - accuracy: 0.8652
# Epoch 00007: val_accuracy improved from 0.87988 to 0.88104, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 78s 17ms/step - loss: 0.4106 - accuracy: 0.8652 - val_loss: 0.3574 - val_accuracy: 0.8810
# Epoch 8/100
# 4610/4610 [==============================] - ETA: 0s - loss: 0.3973 - accuracy: 0.8695
# Epoch 00008: val_accuracy improved from 0.88104 to 0.89075, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 78s 17ms/step - loss: 0.3973 - accuracy: 0.8695 - val_loss: 0.3299 - val_accuracy: 0.8907
# Epoch 9/100
# 4609/4610 [============================>.] - ETA: 0s - loss: 0.3861 - accuracy: 0.8727
# Epoch 00009: val_accuracy improved from 0.89075 to 0.89282, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 78s 17ms/step - loss: 0.3862 - accuracy: 0.8727 - val_loss: 0.3257 - val_accuracy: 0.8928
# Epoch 10/100
# 4610/4610 [==============================] - ETA: 0s - loss: 0.3796 - accuracy: 0.8739
# Epoch 00010: val_accuracy did not improve from 0.89282
# 4610/4610 [==============================] - 76s 16ms/step - loss: 0.3796 - accuracy: 0.8739 - val_loss: 0.3299 - val_accuracy: 0.8922
# Epoch 11/100
# 4610/4610 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.8756
# Epoch 00011: val_accuracy improved from 0.89282 to 0.89404, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 76s 17ms/step - loss: 0.3752 - accuracy: 0.8756 - val_loss: 0.3260 - val_accuracy: 0.8940
# Epoch 12/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3671 - accuracy: 0.8784
# Epoch 00012: val_accuracy improved from 0.89404 to 0.89899, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 75s 16ms/step - loss: 0.3671 - accuracy: 0.8784 - val_loss: 0.3079 - val_accuracy: 0.8990
# Epoch 13/100
# 4610/4610 [==============================] - ETA: 0s - loss: 0.3627 - accuracy: 0.8795
# Epoch 00013: val_accuracy did not improve from 0.89899
# 4610/4610 [==============================] - 73s 16ms/step - loss: 0.3627 - accuracy: 0.8795 - val_loss: 0.3204 - val_accuracy: 0.8956
# Epoch 14/100
# 4610/4610 [==============================] - ETA: 0s - loss: 0.3593 - accuracy: 0.8807
# Epoch 00014: val_accuracy did not improve from 0.89899
# 4610/4610 [==============================] - 72s 16ms/step - loss: 0.3593 - accuracy: 0.8807 - val_loss: 0.3061 - val_accuracy: 0.8977
# Epoch 15/100
# 4607/4610 [============================>.] - ETA: 0s - loss: 0.3546 - accuracy: 0.8824
# Epoch 00015: val_accuracy did not improve from 0.89899
# 4610/4610 [==============================] - 71s 15ms/step - loss: 0.3545 - accuracy: 0.8824 - val_loss: 0.3125 - val_accuracy: 0.8986
# Epoch 16/100
# 4607/4610 [============================>.] - ETA: 0s - loss: 0.3523 - accuracy: 0.8829
# Epoch 00016: val_accuracy improved from 0.89899 to 0.90118, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 73s 16ms/step - loss: 0.3522 - accuracy: 0.8829 - val_loss: 0.3097 - val_accuracy: 0.9012
# Epoch 17/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3512 - accuracy: 0.8840
# Epoch 00017: val_accuracy did not improve from 0.90118
# 4610/4610 [==============================] - 71s 15ms/step - loss: 0.3512 - accuracy: 0.8839 - val_loss: 0.3081 - val_accuracy: 0.9010
# Epoch 18/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3490 - accuracy: 0.8843
# Epoch 00018: val_accuracy improved from 0.90118 to 0.90485, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 72s 16ms/step - loss: 0.3489 - accuracy: 0.8843 - val_loss: 0.2936 - val_accuracy: 0.9048
# Epoch 19/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3442 - accuracy: 0.8855
# Epoch 00019: val_accuracy did not improve from 0.90485
# 4610/4610 [==============================] - 71s 15ms/step - loss: 0.3443 - accuracy: 0.8855 - val_loss: 0.3092 - val_accuracy: 0.8993
# Epoch 20/100
# 4607/4610 [============================>.] - ETA: 0s - loss: 0.3437 - accuracy: 0.8864
# Epoch 00020: val_accuracy did not improve from 0.90485
# 4610/4610 [==============================] - 71s 15ms/step - loss: 0.3437 - accuracy: 0.8864 - val_loss: 0.3071 - val_accuracy: 0.9000
# Epoch 21/100
# 4609/4610 [============================>.] - ETA: 0s - loss: 0.3422 - accuracy: 0.8875
# Epoch 00021: val_accuracy did not improve from 0.90485
# 4610/4610 [==============================] - 71s 15ms/step - loss: 0.3421 - accuracy: 0.8875 - val_loss: 0.3048 - val_accuracy: 0.8992
# Epoch 22/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3379 - accuracy: 0.8884
# Epoch 00022: val_accuracy did not improve from 0.90485
# 4610/4610 [==============================] - 71s 15ms/step - loss: 0.3379 - accuracy: 0.8884 - val_loss: 0.2972 - val_accuracy: 0.9033
# Epoch 23/100
# 4609/4610 [============================>.] - ETA: 0s - loss: 0.3365 - accuracy: 0.8884
# Epoch 00023: val_accuracy did not improve from 0.90485
# 4610/4610 [==============================] - 72s 16ms/step - loss: 0.3365 - accuracy: 0.8884 - val_loss: 0.2995 - val_accuracy: 0.9011
# Epoch 24/100
# 4609/4610 [============================>.] - ETA: 0s - loss: 0.3358 - accuracy: 0.8891
# Epoch 00024: val_accuracy did not improve from 0.90485
# 4610/4610 [==============================] - 71s 15ms/step - loss: 0.3358 - accuracy: 0.8891 - val_loss: 0.3025 - val_accuracy: 0.9030
# Epoch 25/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3354 - accuracy: 0.8890
# Epoch 00025: val_accuracy did not improve from 0.90485
# 4610/4610 [==============================] - 71s 15ms/step - loss: 0.3353 - accuracy: 0.8891 - val_loss: 0.3033 - val_accuracy: 0.8983
# Epoch 26/100
# 4609/4610 [============================>.] - ETA: 0s - loss: 0.3327 - accuracy: 0.8898
# Epoch 00026: val_accuracy did not improve from 0.90485
# 4610/4610 [==============================] - 70s 15ms/step - loss: 0.3328 - accuracy: 0.8898 - val_loss: 0.2935 - val_accuracy: 0.9031
# Epoch 27/100
# 4609/4610 [============================>.] - ETA: 0s - loss: 0.3361 - accuracy: 0.8879
# Epoch 00027: val_accuracy did not improve from 0.90485
# 4610/4610 [==============================] - 71s 15ms/step - loss: 0.3360 - accuracy: 0.8879 - val_loss: 0.2986 - val_accuracy: 0.9012
# Epoch 28/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3337 - accuracy: 0.8896
# Epoch 00028: val_accuracy improved from 0.90485 to 0.90546, saving model to /content/drive/My Drive/TESI/Models/model1_LOW_byclass.h5
# 4610/4610 [==============================] - 72s 16ms/step - loss: 0.3338 - accuracy: 0.8895 - val_loss: 0.2863 - val_accuracy: 0.9055
# Epoch 29/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3346 - accuracy: 0.8883
# Epoch 00029: val_accuracy did not improve from 0.90546
# 4610/4610 [==============================] - 71s 15ms/step - loss: 0.3346 - accuracy: 0.8884 - val_loss: 0.3132 - val_accuracy: 0.8982
# Epoch 30/100
# 4609/4610 [============================>.] - ETA: 0s - loss: 0.3336 - accuracy: 0.8893
# Epoch 00030: val_accuracy did not improve from 0.90546
# 4610/4610 [==============================] - 70s 15ms/step - loss: 0.3335 - accuracy: 0.8893 - val_loss: 0.2969 - val_accuracy: 0.9053
# Epoch 31/100
# 4610/4610 [==============================] - ETA: 0s - loss: 0.3340 - accuracy: 0.8889
# Epoch 00031: val_accuracy did not improve from 0.90546
# 4610/4610 [==============================] - 70s 15ms/step - loss: 0.3340 - accuracy: 0.8889 - val_loss: 0.3002 - val_accuracy: 0.9044
# Epoch 32/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3347 - accuracy: 0.8898
# Epoch 00032: val_accuracy did not improve from 0.90546
# 4610/4610 [==============================] - 70s 15ms/step - loss: 0.3347 - accuracy: 0.8898 - val_loss: 0.2965 - val_accuracy: 0.9033
# Epoch 33/100
# 4609/4610 [============================>.] - ETA: 0s - loss: 0.3309 - accuracy: 0.8901
# Epoch 00033: val_accuracy did not improve from 0.90546
# 4610/4610 [==============================] - 70s 15ms/step - loss: 0.3309 - accuracy: 0.8901 - val_loss: 0.2911 - val_accuracy: 0.9036
# Epoch 34/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3339 - accuracy: 0.8899
# Epoch 00034: val_accuracy did not improve from 0.90546
# 4610/4610 [==============================] - 70s 15ms/step - loss: 0.3339 - accuracy: 0.8899 - val_loss: 0.3072 - val_accuracy: 0.9038
# Epoch 35/100
# 4610/4610 [==============================] - ETA: 0s - loss: 0.3349 - accuracy: 0.8885
# Epoch 00035: val_accuracy did not improve from 0.90546
# 4610/4610 [==============================] - 70s 15ms/step - loss: 0.3349 - accuracy: 0.8885 - val_loss: 0.2930 - val_accuracy: 0.9047
# Epoch 36/100
# 4607/4610 [============================>.] - ETA: 0s - loss: 0.3323 - accuracy: 0.8897
# Epoch 00036: val_accuracy did not improve from 0.90546
# 4610/4610 [==============================] - 70s 15ms/step - loss: 0.3323 - accuracy: 0.8897 - val_loss: 0.2985 - val_accuracy: 0.9029
# Epoch 37/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3348 - accuracy: 0.8891
# Epoch 00037: val_accuracy did not improve from 0.90546
# 4610/4610 [==============================] - 70s 15ms/step - loss: 0.3348 - accuracy: 0.8891 - val_loss: 0.3025 - val_accuracy: 0.9026
# Epoch 38/100
# 4608/4610 [============================>.] - ETA: 0s - loss: 0.3317 - accuracy: 0.8899
# Epoch 00038: val_accuracy did not improve from 0.90546
# Restoring model weights from the end of the best epoch.
# 4610/4610 [==============================] - 70s 15ms/step - loss: 0.3317 - accuracy: 0.8899 - val_loss: 0.2959 - val_accuracy: 0.9025
# Epoch 00038: early stopping

# %%
plt.figure(figsize=(16,9))
# summarize history for accuracy
plt.plot(history1_UPP.history['accuracy'])
plt.plot(history1_UPP.history['val_accuracy'])
plt.title('Model 1 lowercase letters accuracy (with Data Augmentation)')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()
plt.figure(figsize=(16,9))

# summarize history for loss
plt.plot(history1_UPP.history['loss'])
plt.plot(history1_UPP.history['val_loss'])
plt.title('Model 1 lowercase letters loss  (with Data Augmentation)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
lab_test_UPP = tf.keras.utils.to_categorical(lab_test_UPP)

# %%
evaluation = model.evaluate(valid_datagen.flow(im_test_UPP, lab_test_UPP))
# Out:
# 846/846 [==============================] - 9s 11ms/step - loss: 0.2935 - accuracy: 0.9047
