# %%
pip install emnist
# Out:
# Collecting emnist
#   Downloading https://files.pythonhosted.org/packages/d1/f4/78b24acbef9e8fe976dda700f16a3606f3b8363b015bc555f8050fbbd8ac/emnist-0.0-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from emnist) (1.18.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from emnist) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from emnist) (4.41.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2.10)
# Installing collected packages: emnist
# Successfully installed emnist-0.0

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path
from collections import Counter

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from emnist import list_datasets, extract_training_samples, extract_test_samples

# %%
# load emnist dataset 'by class'

images, labels = extract_training_samples('byclass')
images_test, labels_test = extract_test_samples('byclass')
# Out:
# Downloading emnist.zip: 536MB [00:04, 135MB/s]

# %%
# find index of uppercase letters

tr_index_UPP = [i for i in range(len(labels)) if labels[i]>=10 and labels[i] <= 35] 
ts_index_UPP = [i for i in range(len(labels_test)) if labels_test[i]>=10 and labels_test[i] <= 35]

# %%
# save images and labels in uppercase

im_train_UPP = images[tr_index_UPP]
im_test_UPP = images_test[ts_index_UPP]
lab_train_UPP = labels[tr_index_UPP]
lab_test_UPP = labels_test[ts_index_UPP]

# %%
# reformulate labels for application of built-in function 'to_categorical'

alf_UPP = {
       10: 0,
       11: 1,
       12: 2,
       13: 3,
       14: 4,
       15: 5,
       16: 6,
       17: 7,
       18: 8,
       19: 9,
       20: 10,
       21: 11,
       22: 12,
       23: 13,
       24: 14,
       25: 15,
       26: 16,
       27: 17,
       28: 18,
       29: 19,
       30: 20,
       31: 21,
       32: 22,
       33: 23,
       34: 24,
       35: 25,
       }

lab_train_UPP = [alf_UPP[label] for label in lab_train_UPP]
lab_test_UPP = [alf_UPP[label] for label in lab_test_UPP]

# %%
# check labels

lab_train_UPP[0]
# Out:
# 25

# %%
# define image width and height and batch size

# Batch size for training and validation
batch_size = 32

# Desired image dimensions
img_width = 28
img_height = 28

# %%
# split training set in traininig and validation set

def split_data(images, labels, train_size=0.9, shuffle=True):
    # 1. Get the total size of the dataset
    size = len(images)
    # 2. Make an indices array and shuffle it, if required
    indices = np.arange(size)
    if shuffle:
        np.random.shuffle(indices)
    # 3. Get the size of training samples
    train_samples = int(size * train_size)
    # 4. Split data into training and validation sets
    x_train, y_train = images[indices[:train_samples]], labels[indices[:train_samples]]
    x_valid, y_valid = images[indices[train_samples:]], labels[indices[train_samples:]]
    return x_train, x_valid, y_train, y_valid

# %%
# Splitting data into training and validation sets
x_train_UPP, x_valid_UPP, y_train_UPP, y_valid_UPP = split_data(np.array(im_train_UPP), np.array(lab_train_UPP))

# %%
# to categorical 

y_train_UPP = tf.keras.utils.to_categorical(y_train_UPP, 26)
y_valid_UPP = tf.keras.utils.to_categorical(y_valid_UPP, 26)
lab_test_UPP = tf.keras.utils.to_categorical(lab_test_UPP, 26)

# %%
# normalize training, validation and test data

x_train_UPP = tf.keras.utils.normalize(x_train_UPP, axis=1)
x_valid_UPP = tf.keras.utils.normalize(x_valid_UPP, axis=1)
im_test_UPP = tf.keras.utils.normalize(im_test_UPP, axis=1)

# %%
# build model

def build_model():
    # Inputs to the model
    input_img = layers.Input(
        shape=(img_width, img_height, 1), name="image", dtype="float32"
    )
    # First conv block
    x = layers.Conv2D(
        256,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv1",
    )(input_img)
    x = layers.MaxPooling2D((2, 2),padding='same',name="pool1")(x)

    # Second conv block
    x = layers.Conv2D(
        128,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv2",
    )(x)
    x = layers.MaxPooling2D((2, 2), padding='same',name="pool2")(x)

    # Third conv block
    x = layers.Conv2D(
        64,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv3",
    )(x)
    x = layers.MaxPooling2D((2, 2), padding='same',name="pool3")(x)
    x = layers.Flatten()(x)
    
    # MLP + Output layer
    x = layers.Dense(units=128, activation='sigmoid', name='dense_1')(x)
    output = layers.Dense(units=26, activation="softmax", name="dense2")(x)

    # Define the model
    model = keras.models.Model(
        inputs=input_img, outputs=output, name="ocr_model_v1"
    )
    # Optimizer
    opt = keras.optimizers.Adam()
    # Compile the model and return
    model.compile(loss='categorical_crossentropy',optimizer=opt, metrics=['accuracy'])

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "ocr_model_v1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image (InputLayer)           [(None, 28, 28, 1)]       0
# _________________________________________________________________
# Conv1 (Conv2D)               (None, 28, 28, 256)       2560
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 14, 14, 256)       0
# _________________________________________________________________
# Conv2 (Conv2D)               (None, 14, 14, 128)       295040
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 7, 7, 128)         0
# _________________________________________________________________
# Conv3 (Conv2D)               (None, 7, 7, 64)          73792
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense2 (Dense)               (None, 26)                3354
# =================================================================
# Total params: 505,946
# Trainable params: 505,946
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, to_file='/content/drive/My Drive/TESI/Models/Immagini/model3_byclass_upper_noDA.png')

# %%
epochs = 100
early_stopping_patience = 10
# Add early stopping
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_accuracy", patience=early_stopping_patience, restore_best_weights=True, verbose=1
)

# Model CheckPoint
cp = keras.callbacks.ModelCheckpoint('/content/drive/My Drive/TESI/Models/model3_UPP_byclass_noDA.h5',
                                     verbose=1,
                                     monitor='val_accuracy',
                                     save_best_only=True)

# %%
# fit model
history1_UPP = model.fit(x_train_UPP,y_train_UPP,
                    validation_data=(x_valid_UPP,y_valid_UPP),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[cp, early_stopping])
# Out:
# Epoch 1/100
# 5315/5315 [==============================] - ETA: 0s - loss: 0.2178 - accuracy: 0.9444
# Epoch 00001: val_accuracy improved from -inf to 0.96878, saving model to /content/drive/My Drive/TESI/Models/model3_UPP_byclass_noDA.h5
# 5315/5315 [==============================] - 68s 13ms/step - loss: 0.2178 - accuracy: 0.9444 - val_loss: 0.1094 - val_accuracy: 0.9688
# Epoch 2/100
# 5313/5315 [============================>.] - ETA: 0s - loss: 0.0910 - accuracy: 0.9745
# Epoch 00002: val_accuracy improved from 0.96878 to 0.97359, saving model to /content/drive/My Drive/TESI/Models/model3_UPP_byclass_noDA.h5
# 5315/5315 [==============================] - 67s 13ms/step - loss: 0.0910 - accuracy: 0.9746 - val_loss: 0.0923 - val_accuracy: 0.9736
# Epoch 3/100
# 5314/5315 [============================>.] - ETA: 0s - loss: 0.0770 - accuracy: 0.9784
# Epoch 00003: val_accuracy improved from 0.97359 to 0.97756, saving model to /content/drive/My Drive/TESI/Models/model3_UPP_byclass_noDA.h5
# 5315/5315 [==============================] - 67s 13ms/step - loss: 0.0770 - accuracy: 0.9784 - val_loss: 0.0815 - val_accuracy: 0.9776
# Epoch 4/100
# 5313/5315 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9805
# Epoch 00004: val_accuracy did not improve from 0.97756
# 5315/5315 [==============================] - 67s 13ms/step - loss: 0.0699 - accuracy: 0.9805 - val_loss: 0.0826 - val_accuracy: 0.9775
# Epoch 5/100
# 5315/5315 [==============================] - ETA: 0s - loss: 0.0669 - accuracy: 0.9811
# Epoch 00005: val_accuracy improved from 0.97756 to 0.97772, saving model to /content/drive/My Drive/TESI/Models/model3_UPP_byclass_noDA.h5
# 5315/5315 [==============================] - 67s 13ms/step - loss: 0.0669 - accuracy: 0.9811 - val_loss: 0.0822 - val_accuracy: 0.9777
# Epoch 6/100
# 5313/5315 [============================>.] - ETA: 0s - loss: 0.0653 - accuracy: 0.9817
# Epoch 00006: val_accuracy did not improve from 0.97772
# 5315/5315 [==============================] - 66s 12ms/step - loss: 0.0653 - accuracy: 0.9817 - val_loss: 0.0811 - val_accuracy: 0.9776
# Epoch 7/100
# 5313/5315 [============================>.] - ETA: 0s - loss: 0.0650 - accuracy: 0.9821
# Epoch 00007: val_accuracy did not improve from 0.97772
# 5315/5315 [==============================] - 66s 12ms/step - loss: 0.0650 - accuracy: 0.9821 - val_loss: 0.0916 - val_accuracy: 0.9752
# Epoch 8/100
# 5312/5315 [============================>.] - ETA: 0s - loss: 0.0652 - accuracy: 0.9819
# Epoch 00008: val_accuracy did not improve from 0.97772
# 5315/5315 [==============================] - 66s 12ms/step - loss: 0.0652 - accuracy: 0.9819 - val_loss: 0.0914 - val_accuracy: 0.9741
# Epoch 9/100
# 5313/5315 [============================>.] - ETA: 0s - loss: 0.0638 - accuracy: 0.9823
# Epoch 00009: val_accuracy improved from 0.97772 to 0.97836, saving model to /content/drive/My Drive/TESI/Models/model3_UPP_byclass_noDA.h5
# 5315/5315 [==============================] - 68s 13ms/step - loss: 0.0638 - accuracy: 0.9823 - val_loss: 0.0802 - val_accuracy: 0.9784
# Epoch 10/100
# 5312/5315 [============================>.] - ETA: 0s - loss: 0.0638 - accuracy: 0.9820
# Epoch 00010: val_accuracy did not improve from 0.97836
# 5315/5315 [==============================] - 66s 12ms/step - loss: 0.0638 - accuracy: 0.9820 - val_loss: 0.0903 - val_accuracy: 0.9757
# Epoch 11/100
# 5314/5315 [============================>.] - ETA: 0s - loss: 0.0666 - accuracy: 0.9814
# Epoch 00011: val_accuracy did not improve from 0.97836
# 5315/5315 [==============================] - 66s 12ms/step - loss: 0.0666 - accuracy: 0.9814 - val_loss: 0.0881 - val_accuracy: 0.9759
# Epoch 12/100
# 5313/5315 [============================>.] - ETA: 0s - loss: 0.0711 - accuracy: 0.9799
# Epoch 00012: val_accuracy did not improve from 0.97836
# 5315/5315 [==============================] - 66s 12ms/step - loss: 0.0711 - accuracy: 0.9799 - val_loss: 0.0870 - val_accuracy: 0.9759
# Epoch 13/100
# 5314/5315 [============================>.] - ETA: 0s - loss: 0.0729 - accuracy: 0.9794
# Epoch 00013: val_accuracy did not improve from 0.97836
# 5315/5315 [==============================] - 66s 12ms/step - loss: 0.0729 - accuracy: 0.9794 - val_loss: 0.0934 - val_accuracy: 0.9752
# Epoch 14/100
# 5315/5315 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9800
# Epoch 00014: val_accuracy did not improve from 0.97836
# 5315/5315 [==============================] - 67s 13ms/step - loss: 0.0721 - accuracy: 0.9800 - val_loss: 0.0919 - val_accuracy: 0.9749
# Epoch 15/100
# 5314/5315 [============================>.] - ETA: 0s - loss: 0.0743 - accuracy: 0.9789
# Epoch 00015: val_accuracy did not improve from 0.97836
# 5315/5315 [==============================] - 66s 12ms/step - loss: 0.0743 - accuracy: 0.9789 - val_loss: 0.0930 - val_accuracy: 0.9758
# Epoch 16/100
# 5315/5315 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9784
# Epoch 00016: val_accuracy did not improve from 0.97836
# 5315/5315 [==============================] - 66s 12ms/step - loss: 0.0760 - accuracy: 0.9784 - val_loss: 0.0889 - val_accuracy: 0.9776
# Epoch 17/100
# 5311/5315 [============================>.] - ETA: 0s - loss: 0.0776 - accuracy: 0.9786
# Epoch 00017: val_accuracy did not improve from 0.97836
# 5315/5315 [==============================] - 66s 12ms/step - loss: 0.0776 - accuracy: 0.9786 - val_loss: 0.0900 - val_accuracy: 0.9762
# Epoch 18/100
# 5311/5315 [============================>.] - ETA: 0s - loss: 0.0792 - accuracy: 0.9774
# Epoch 00018: val_accuracy did not improve from 0.97836
# 5315/5315 [==============================] - 67s 13ms/step - loss: 0.0792 - accuracy: 0.9774 - val_loss: 0.0982 - val_accuracy: 0.9722
# Epoch 19/100
# 5311/5315 [============================>.] - ETA: 0s - loss: 0.0782 - accuracy: 0.9782
# Epoch 00019: val_accuracy did not improve from 0.97836
# Restoring model weights from the end of the best epoch.
# 5315/5315 [==============================] - 66s 12ms/step - loss: 0.0782 - accuracy: 0.9782 - val_loss: 0.0906 - val_accuracy: 0.9768
# Epoch 00019: early stopping

# %%
plt.figure(figsize=(16,9))
# summarize history for accuracy
plt.plot(history1_UPP.history['accuracy'])
plt.plot(history1_UPP.history['val_accuracy'])
plt.title('Model 3 uppercase letters accuracy (without Data Augmentation)')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()
plt.figure(figsize=(16,9))

# summarize history for loss
plt.plot(history1_UPP.history['loss'])
plt.plot(history1_UPP.history['val_loss'])
plt.title('Model 3 uppercase letters loss (without Data Augmentation)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
evaluation = model.evaluate(im_test_UPP, lab_test_UPP)
# Out:
# 980/980 [==============================] - 6s 6ms/step - loss: 0.0833 - accuracy: 0.9773

# %%
evaluation
# Out:
# [0.08508741855621338, 0.9762968420982361]
