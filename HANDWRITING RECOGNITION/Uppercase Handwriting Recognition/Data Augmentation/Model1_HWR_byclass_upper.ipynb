# %%
pip install emnist
# Out:
# Collecting emnist
#   Downloading https://files.pythonhosted.org/packages/d1/f4/78b24acbef9e8fe976dda700f16a3606f3b8363b015bc555f8050fbbd8ac/emnist-0.0-py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from emnist) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from emnist) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from emnist) (1.18.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (3.0.4)
# Installing collected packages: emnist
# Successfully installed emnist-0.0

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path
from collections import Counter

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from emnist import list_datasets, extract_training_samples, extract_test_samples

# %%
# load emnist dataset 'by class'

images, labels = extract_training_samples('byclass')
images_test, labels_test = extract_test_samples('byclass')
# Out:
# Downloading emnist.zip: 536MB [00:03, 142MB/s]

# %%
# find index of uppercase letters

tr_index_UPP = [i for i in range(len(labels)) if labels[i]>=10 and labels[i] <= 35] 
ts_index_UPP = [i for i in range(len(labels_test)) if labels_test[i]>=10 and labels_test[i] <= 35]

# %%
# save images and labels in uppercase

im_train_UPP = images[tr_index_UPP]
im_test_UPP = images_test[ts_index_UPP]
lab_train_UPP = labels[tr_index_UPP]
lab_test_UPP = labels_test[ts_index_UPP]

# %%
# reformulate labels for application of built-in function 'to_categorical'

alf_UPP = {
       10: 0,
       11: 1,
       12: 2,
       13: 3,
       14: 4,
       15: 5,
       16: 6,
       17: 7,
       18: 8,
       19: 9,
       20: 10,
       21: 11,
       22: 12,
       23: 13,
       24: 14,
       25: 15,
       26: 16,
       27: 17,
       28: 18,
       29: 19,
       30: 20,
       31: 21,
       32: 22,
       33: 23,
       34: 24,
       35: 25,
       }

lab_train_UPP = [alf_UPP[label] for label in lab_train_UPP]
lab_test_UPP = [alf_UPP[label] for label in lab_test_UPP]

# %%
# check labels

lab_train_UPP[0]
# Out:
# 25

# %%
# define image width and height and batch size

# Batch size for training and validation
batch_size = 32

# Desired image dimensions
img_width = 28
img_height = 28

# %%
# split training set in traininig and validation set

def split_data(images, labels, train_size=0.9, shuffle=True):
    # 1. Get the total size of the dataset
    size = len(images)
    # 2. Make an indices array and shuffle it, if required
    indices = np.arange(size)
    if shuffle:
        np.random.shuffle(indices)
    # 3. Get the size of training samples
    train_samples = int(size * train_size)
    # 4. Split data into training and validation sets
    x_train, y_train = images[indices[:train_samples]], labels[indices[:train_samples]]
    x_valid, y_valid = images[indices[train_samples:]], labels[indices[train_samples:]]
    return x_train, x_valid, y_train, y_valid

# %%
# Splitting data into training and validation sets
x_train_UPP, x_valid_UPP, y_train_UPP, y_valid_UPP = split_data(np.array(im_train_UPP), np.array(lab_train_UPP))

# %%
# to categorical 

y_train_UPP = tf.keras.utils.to_categorical(y_train_UPP, 26)
y_valid_UPP = tf.keras.utils.to_categorical(y_valid_UPP, 26)

# %%
# normalize training, validation and test data

x_train_UPP = tf.keras.utils.normalize(x_train_UPP, axis=1)
x_valid_UPP = tf.keras.utils.normalize(x_valid_UPP, axis=1)
im_test_UPP = tf.keras.utils.normalize(im_test_UPP, axis=1)

# %%
# using data augmentation

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(featurewise_center=True,
                                                          featurewise_std_normalization=True,
                                                          rotation_range=20,
                                                          width_shift_range=0.2,
                                                          height_shift_range=0.2,
                                                          horizontal_flip=True)
valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(featurewise_center=True,
                                                          featurewise_std_normalization=True,
                                                          rotation_range=20,
                                                          width_shift_range=0.2,
                                                          height_shift_range=0.2,
                                                          horizontal_flip=True)

x_train_UPP = np.reshape(x_train_UPP, (len(x_train_UPP),img_width, img_width, 1))
x_valid_UPP = np.reshape(x_valid_UPP, (len(x_valid_UPP),img_width, img_width, 1))
im_test_UPP = np.reshape(im_test_UPP, (len(im_test_UPP), img_width, img_height, 1))

train_datagen.fit(x_train_UPP)
valid_datagen.fit(x_valid_UPP)

# %%
# build model

def build_model():
    # Inputs to the model
    input_img = layers.Input(
        shape=(img_width, img_height, 1), name="image", dtype="float32"
    )
    # First conv block
    x = layers.Conv2D(
        64,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv1",
    )(input_img)
    x = layers.MaxPooling2D((2, 2),padding='same',name="pool1")(x)

    # Second conv block
    x = layers.Conv2D(
        128,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv2",
    )(x)
    x = layers.MaxPooling2D((2, 2), padding='same',name="pool2")(x)
    #x = layers.Flatten()(x)
    # We have used two max pool with pool size and strides 2.
    # Hence, downsampled feature maps are 4x smaller. The number of
    # filters in the last layer is 64. Reshape accordingly before
    # passing the output to the RNN part of the model
    new_shape = ((img_width // 4), (img_height // 4) * 128)
    x = layers.Reshape(target_shape=new_shape, name="reshape")(x)
    x = layers.Dense(64, activation="relu", name="dense1")(x)
    x = layers.Dropout(0.2)(x)

    # RNNs
    x = layers.Bidirectional(layers.LSTM(64, return_sequences=True, dropout=0.25, name='bilstm1'))(x)
    #x = layers.Flatten()(x)
    x = layers.Bidirectional(layers.LSTM(32, return_sequences=True, dropout=0.25, name='bilstm2'))(x)
    x = layers.Flatten()(x)
    # Output layer
    x = layers.Dense(units=128, activation='sigmoid', name='dense_1')(x)
    output = layers.Dense(units=26, activation="softmax", name="dense2")(x)

    # Define the model
    model = keras.models.Model(
        inputs=input_img, outputs=output, name="ocr_model_v1"
    )
    # Optimizer
    opt = keras.optimizers.Adam()
    # Compile the model and return
    model.compile(loss='categorical_crossentropy',optimizer=opt, metrics=['accuracy'])

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "ocr_model_v1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image (InputLayer)           [(None, 28, 28, 1)]       0
# _________________________________________________________________
# Conv1 (Conv2D)               (None, 28, 28, 64)        640
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 14, 14, 64)        0
# _________________________________________________________________
# Conv2 (Conv2D)               (None, 14, 14, 128)       73856
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 7, 7, 128)         0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 896)            0
# _________________________________________________________________
# dense1 (Dense)               (None, 7, 64)             57408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 64)             0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 7, 128)            66048
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 7, 64)             41216
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 448)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               57472
# _________________________________________________________________
# dense2 (Dense)               (None, 26)                3354
# =================================================================
# Total params: 299,994
# Trainable params: 299,994
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, to_file='/content/drive/My Drive/TESI/Models/Immagini/model1_byclass_upper.png')

# %%
epochs = 100
early_stopping_patience = 10
# Add early stopping
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_accuracy", patience=early_stopping_patience, restore_best_weights=True, verbose=1
)

# Model CheckPoint
cp = keras.callbacks.ModelCheckpoint('/content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5',
                                     verbose=1,
                                     monitor='val_accuracy',
                                     save_best_only=True,
                                     mode='max')

# %%
# fit model
history1_UPP = model.fit(train_datagen.flow(x_train_UPP,y_train_UPP, batch_size=batch_size),
                    validation_data=valid_datagen.flow(x_valid_UPP,y_valid_UPP, batch_size=batch_size),
                    steps_per_epoch=len(x_train_UPP)//batch_size,
                    validation_steps=len(x_valid_UPP)//batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[cp, early_stopping])
# Out:
# Epoch 1/100
# 5314/5314 [==============================] - ETA: 0s - loss: 0.8595 - accuracy: 0.7350
# Epoch 00001: val_accuracy improved from -inf to 0.87887, saving model to /content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5
# 5314/5314 [==============================] - 85s 16ms/step - loss: 0.8595 - accuracy: 0.7350 - val_loss: 0.3993 - val_accuracy: 0.8789
# Epoch 2/100
# 5314/5314 [==============================] - ETA: 0s - loss: 0.4371 - accuracy: 0.8641
# Epoch 00002: val_accuracy improved from 0.87887 to 0.90863, saving model to /content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5
# 5314/5314 [==============================] - 82s 16ms/step - loss: 0.4371 - accuracy: 0.8641 - val_loss: 0.2998 - val_accuracy: 0.9086
# Epoch 3/100
# 5313/5314 [============================>.] - ETA: 0s - loss: 0.3556 - accuracy: 0.8903
# Epoch 00003: val_accuracy improved from 0.90863 to 0.91780, saving model to /content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.3556 - accuracy: 0.8903 - val_loss: 0.2772 - val_accuracy: 0.9178
# Epoch 4/100
# 5311/5314 [============================>.] - ETA: 0s - loss: 0.3167 - accuracy: 0.9024
# Epoch 00004: val_accuracy improved from 0.91780 to 0.92542, saving model to /content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.3167 - accuracy: 0.9024 - val_loss: 0.2555 - val_accuracy: 0.9254
# Epoch 5/100
# 5313/5314 [============================>.] - ETA: 0s - loss: 0.2936 - accuracy: 0.9103
# Epoch 00005: val_accuracy improved from 0.92542 to 0.93469, saving model to /content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5
# 5314/5314 [==============================] - 82s 15ms/step - loss: 0.2936 - accuracy: 0.9103 - val_loss: 0.2191 - val_accuracy: 0.9347
# Epoch 6/100
# 5311/5314 [============================>.] - ETA: 0s - loss: 0.2778 - accuracy: 0.9148
# Epoch 00006: val_accuracy did not improve from 0.93469
# 5314/5314 [==============================] - 80s 15ms/step - loss: 0.2778 - accuracy: 0.9148 - val_loss: 0.2235 - val_accuracy: 0.9336
# Epoch 7/100
# 5313/5314 [============================>.] - ETA: 0s - loss: 0.2660 - accuracy: 0.9181
# Epoch 00007: val_accuracy improved from 0.93469 to 0.93893, saving model to /content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.2660 - accuracy: 0.9181 - val_loss: 0.2112 - val_accuracy: 0.9389
# Epoch 8/100
# 5311/5314 [============================>.] - ETA: 0s - loss: 0.2593 - accuracy: 0.9210
# Epoch 00008: val_accuracy did not improve from 0.93893
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.2594 - accuracy: 0.9210 - val_loss: 0.2047 - val_accuracy: 0.9386
# Epoch 9/100
# 5311/5314 [============================>.] - ETA: 0s - loss: 0.2491 - accuracy: 0.9240
# Epoch 00009: val_accuracy improved from 0.93893 to 0.94274, saving model to /content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.2491 - accuracy: 0.9240 - val_loss: 0.1940 - val_accuracy: 0.9427
# Epoch 10/100
# 5312/5314 [============================>.] - ETA: 0s - loss: 0.2461 - accuracy: 0.9251
# Epoch 00010: val_accuracy improved from 0.94274 to 0.94338, saving model to /content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5
# 5314/5314 [==============================] - 82s 15ms/step - loss: 0.2461 - accuracy: 0.9251 - val_loss: 0.1938 - val_accuracy: 0.9434
# Epoch 11/100
# 5313/5314 [============================>.] - ETA: 0s - loss: 0.2385 - accuracy: 0.9281
# Epoch 00011: val_accuracy improved from 0.94338 to 0.94460, saving model to /content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5
# 5314/5314 [==============================] - 83s 16ms/step - loss: 0.2385 - accuracy: 0.9280 - val_loss: 0.1906 - val_accuracy: 0.9446
# Epoch 12/100
# 5312/5314 [============================>.] - ETA: 0s - loss: 0.2338 - accuracy: 0.9286
# Epoch 00012: val_accuracy did not improve from 0.94460
# 5314/5314 [==============================] - 82s 15ms/step - loss: 0.2339 - accuracy: 0.9286 - val_loss: 0.1970 - val_accuracy: 0.9432
# Epoch 13/100
# 5314/5314 [==============================] - ETA: 0s - loss: 0.2325 - accuracy: 0.9290
# Epoch 00013: val_accuracy did not improve from 0.94460
# 5314/5314 [==============================] - 82s 15ms/step - loss: 0.2325 - accuracy: 0.9290 - val_loss: 0.1952 - val_accuracy: 0.9437
# Epoch 14/100
# 5313/5314 [============================>.] - ETA: 0s - loss: 0.2295 - accuracy: 0.9306
# Epoch 00014: val_accuracy improved from 0.94460 to 0.94682, saving model to /content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.2295 - accuracy: 0.9306 - val_loss: 0.1825 - val_accuracy: 0.9468
# Epoch 15/100
# 5314/5314 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9306
# Epoch 00015: val_accuracy improved from 0.94682 to 0.95159, saving model to /content/drive/My Drive/TESI/Models/model1_UPP_byclass.h5
# 5314/5314 [==============================] - 82s 15ms/step - loss: 0.2291 - accuracy: 0.9306 - val_loss: 0.1696 - val_accuracy: 0.9516
# Epoch 16/100
# 5312/5314 [============================>.] - ETA: 0s - loss: 0.2246 - accuracy: 0.9313
# Epoch 00016: val_accuracy did not improve from 0.95159
# 5314/5314 [==============================] - 80s 15ms/step - loss: 0.2246 - accuracy: 0.9313 - val_loss: 0.1744 - val_accuracy: 0.9492
# Epoch 17/100
# 5313/5314 [============================>.] - ETA: 0s - loss: 0.2218 - accuracy: 0.9322
# Epoch 00017: val_accuracy did not improve from 0.95159
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.2218 - accuracy: 0.9322 - val_loss: 0.1781 - val_accuracy: 0.9501
# Epoch 18/100
# 5313/5314 [============================>.] - ETA: 0s - loss: 0.2226 - accuracy: 0.9328
# Epoch 00018: val_accuracy did not improve from 0.95159
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.2226 - accuracy: 0.9328 - val_loss: 0.1923 - val_accuracy: 0.9442
# Epoch 19/100
# 5313/5314 [============================>.] - ETA: 0s - loss: 0.2219 - accuracy: 0.9332
# Epoch 00019: val_accuracy did not improve from 0.95159
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.2220 - accuracy: 0.9332 - val_loss: 0.1687 - val_accuracy: 0.9507
# Epoch 20/100
# 5311/5314 [============================>.] - ETA: 0s - loss: 0.2181 - accuracy: 0.9334
# Epoch 00020: val_accuracy did not improve from 0.95159
# 5314/5314 [==============================] - 82s 15ms/step - loss: 0.2181 - accuracy: 0.9334 - val_loss: 0.1868 - val_accuracy: 0.9441
# Epoch 21/100
# 5313/5314 [============================>.] - ETA: 0s - loss: 0.2194 - accuracy: 0.9333
# Epoch 00021: val_accuracy did not improve from 0.95159
# 5314/5314 [==============================] - 82s 15ms/step - loss: 0.2194 - accuracy: 0.9333 - val_loss: 0.1797 - val_accuracy: 0.9495
# Epoch 22/100
# 5313/5314 [============================>.] - ETA: 0s - loss: 0.2182 - accuracy: 0.9337
# Epoch 00022: val_accuracy did not improve from 0.95159
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.2183 - accuracy: 0.9337 - val_loss: 0.1693 - val_accuracy: 0.9513
# Epoch 23/100
# 5313/5314 [============================>.] - ETA: 0s - loss: 0.2162 - accuracy: 0.9345
# Epoch 00023: val_accuracy did not improve from 0.95159
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.2163 - accuracy: 0.9345 - val_loss: 0.1810 - val_accuracy: 0.9477
# Epoch 24/100
# 5314/5314 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.9341
# Epoch 00024: val_accuracy did not improve from 0.95159
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.2173 - accuracy: 0.9341 - val_loss: 0.1660 - val_accuracy: 0.9503
# Epoch 25/100
# 5314/5314 [==============================] - ETA: 0s - loss: 0.2169 - accuracy: 0.9343
# Epoch 00025: val_accuracy did not improve from 0.95159
# Restoring model weights from the end of the best epoch.
# 5314/5314 [==============================] - 81s 15ms/step - loss: 0.2169 - accuracy: 0.9343 - val_loss: 0.1735 - val_accuracy: 0.9502
# Epoch 00025: early stopping

# %%
plt.figure(figsize=(16,9))
# summarize history for accuracy
plt.plot(history1_UPP.history['accuracy'])
plt.plot(history1_UPP.history['val_accuracy'])
plt.title('Model 1 uppercase letters accuracy (with Data Augmentation)')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()
plt.figure(figsize=(16,9))

# summarize history for loss
plt.plot(history1_UPP.history['loss'])
plt.plot(history1_UPP.history['val_loss'])
plt.title('Model 1 uppercase letters loss  (with Data Augmentation)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
lab_test_UPP = tf.keras.utils.to_categorical(lab_test_UPP)

# %%
evaluation = model.evaluate(valid_datagen.flow(im_test_UPP, lab_test_UPP))
# Out:
# 980/980 [==============================] - 11s 11ms/step - loss: 0.1741 - accuracy: 0.9484
